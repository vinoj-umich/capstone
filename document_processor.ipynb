# %%
import pandas as pd
import fitz  # PyMuPDF for PDF processing
from tqdm.auto import tqdm  # For progress bars
import re  # For regex operations
import chromadb
from sentence_transformers import SentenceTransformer  # For embeddings
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
import logging
import spacy
from transformers import T5ForConditionalGeneration, T5Tokenizer

# %%
# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
def log_output(string):
    #logger.info(string)
    return

# %% [markdown]
# # Step 1: Text Formatter

# %%
class TextFormatter(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        formatted_texts = []
        
        for pages_and_text in X:
            # Replace newlines with spaces and strip leading/trailing spaces
            formatted_text = pages_and_text['text'].replace("\n", " ").strip()
            formatted_page_text = {"page_number": pages_and_text['page_number'], "formatted_text": formatted_text}
            formatted_texts.append(formatted_page_text)

        log_output("Formatted texts successfully.")
        return formatted_texts

# %% [markdown]
# # Step 2: Open and Read PDF

# %%
class PDFReader(BaseEstimator, TransformerMixin):
    def __init__(self, pdf_path):
        self.pdf_path = pdf_path

    def fit(self, X, y=None):
        return self

    def transform(self, X=None):
        """
        Reads a PDF file and extracts text from each page.

        Returns:
            list: A list of dictionaries, each containing the page number and its text.
        """
        try:
            doc = fitz.open(self.pdf_path)
        except Exception as e:
            logger.error(f"Failed to open PDF file: {self.pdf_path}. Error: {e}")

            return []
        
        

        pages_and_texts = []
        for page_number in tqdm(range(len(doc)), desc="Reading PDF pages"):
            page = doc[page_number]
            text = page.get_text()
            pages_and_texts.append({"page_number": page_number, "text": text})

        logger.info(f"Successfully read {len(pages_and_texts)} pages from {self.pdf_path}")
        return pages_and_texts

# %% [markdown]
# #  Transformer to detect and convert bullet points

# %%
import re
from sklearn.base import BaseEstimator, TransformerMixin
import logging

# Set up logging
logger = logging.getLogger(__name__)

class BulletPointTransformer(BaseEstimator, TransformerMixin):
    """
    Transformer to detect and convert bullet points into a structured format.
    This ensures only successive bullet points are combined into one sentence.
    """
    
    def __init__(self):
        """
        Initializes the BulletPointTransformer.
        """
        pass

    def fit(self, X, y=None):
        """
        Fit method does nothing as the transformer doesn't require fitting.
        """
        return self

    def transform(self, X):
        """
        Transform the input data by identifying and formatting bullet points.
        
        :param X: List of documents or paragraphs to process
        :return: List of documents with bullet points properly formatted
        """
        if not X:
            logger.warning("Input data is empty.")
            return []

        transformed_data = []

        for item in X:
            if isinstance(item, dict):
                if 'formatted_text' in item:
                    text = item['formatted_text'].strip()
                    # Apply bullet point transformation
                    transformed_text = self._transform_bullet_points(text)
                    item['formatted_text'] = transformed_text
                    transformed_data.append(item)
                else:
                    logger.warning(f"Missing 'formatted_text' key in item: {item}")
            else:
                logger.error(f"Unexpected item format: {item}")
        
        return transformed_data

    def _transform_bullet_points(self, text):
        """
        Detect and combine only successive bullet points into a single sentence.
        Bullet points can be identified by common characters such as *, -, or •.
        
        :param text: The input text to process.
        :return: Text with only successive bullet points combined into a single sentence.
        """
        # Regular expression to match bullet points (handles *, -, or •)
        bullet_point_pattern = r'([*\-•])\s?(.*?)(?=\n|\r|\Z|\s*$)'  # Match bullet points

        # Match all bullet points
        bullet_points = re.findall(bullet_point_pattern, text)

        # If there are bullet points, combine only successive ones into a single sentence
        if bullet_points:
            # Iterate through the bullet points and combine only successive ones
            combined_bullet_points = []
            last_bullet = None
            for bp in bullet_points:
                if last_bullet is None:  # First bullet point
                    combined_bullet_points.append(bp[1].strip())
                else:  # Add only if successive bullet points
                    combined_bullet_points.append(bp[1].strip())
                last_bullet = bp
            
            # Join all successive bullet points into a single sentence
            combined_bullet_points_sentence = " ".join(combined_bullet_points) + "."
            # Replace the bullet points section with the combined sentence
            text = re.sub(bullet_point_pattern, "", text)  # Remove old bullet points
            text = f"{combined_bullet_points_sentence} {text}"  # Add combined bullet points as a sentence

        return text

# %% [markdown]
# # SentenceChunkerWithSummarization

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer
from sklearn.base import BaseEstimator, TransformerMixin
import spacy
import logging
import hashlib


# Set up logging
logger = logging.getLogger(__name__)

class SentenceChunkerWithSummarization(BaseEstimator, TransformerMixin):
    def __init__(self, max_sentences_per_chunk=10, max_summary_length=500, num_beams=4):
        """
        Initialize the SentenceChunkerWithSummarization.
        
        :param max_sentences_per_chunk: The maximum number of sentences per chunk.
        :param max_summary_length: Maximum length of the generated summary.
        :param num_beams: Number of beams for beam search during summary generation.
        """
        self.max_sentences_per_chunk = max_sentences_per_chunk
        self.max_summary_length = max_summary_length
        self.num_beams = num_beams
        
        # Load the SpaCy model and add the sentencizer
        self.nlp = spacy.blank("en")
        self.nlp.add_pipe("sentencizer")
        
        # Load the T5 model and tokenizer
        self.model = T5ForConditionalGeneration.from_pretrained('t5-small')
        self.tokenizer = T5Tokenizer.from_pretrained('t5-small')

    def fit(self, X, y=None):
        """
        Fit method does nothing as the model doesn't require fitting.
        """
        return self

    def generate_summary(self, text):
        """
        Generate a summary for a given text using the T5 model.
        
        :param text: The input text to summarize
        :return: The summarized text
        """
        if not text or not isinstance(text, str):
            logger.warning("Received invalid text input.")
            return "Invalid input: Empty or non-string text"

        # Tokenize the input with the T5 summarization prompt
        input_tokens = self.tokenizer.encode("summarize: " + text, return_tensors='pt')

        # Generate the summary using the model
        # max_length=150,  # Increase the max_length for a longer summary
        # min_length=50,   # Set a minimum length to prevent too short summaries
        # num_beams=4,     # Use beam search for better quality summaries
        # early_stopping=True,  # Stop early when the model is confident
        # length_penalty=1.5,   # Apply a penalty to make sure summaries are not too short
        output = self.model.generate(input_tokens, min_length=50, max_length=self.max_summary_length, num_beams=self.num_beams, early_stopping=True,  length_penalty=1.5)

        # Decode the summary
        summary = self.tokenizer.decode(output[0], skip_special_tokens=True)
        return summary

    def generate_unique_id(self, sentence_chunk):
        """
        Generate a unique ID from a sentence chunk using SHA-256 hash.

        :param sentence_chunk: The input sentence to generate the ID from.
        :return: A unique ID (SHA-256 hash) as a hexadecimal string.
        """
        # Step 1: Preprocess the sentence (optional, you could strip, lowercase, etc.)
        processed_chunk = sentence_chunk.strip().lower()

        # Step 2: Create the SHA-256 hash of the sentence
        unique_id = hashlib.sha256(processed_chunk.encode()).hexdigest()

        return unique_id

    def transform(self, X):
        """
        Transform the input data by chunking sentences and summarizing each chunk.
        
        :param X: List of documents or paragraphs to process
        :return: List of dictionaries with sentence chunks and their summaries
        """
        if not X:
            logger.warning("Input data is empty.")
            return []

        pages_and_chunks = []
        sentences = []
        pages = []

        # Extract sentences and page numbers from the input
        for item in X:
            if isinstance(item, dict):
                if 'formatted_text' in item and 'page_number' in item:
                    text = item['formatted_text'].strip()
                    page_number = item['page_number']
                    if text:  # Check if text is not empty
                        doc = self.nlp(text)  # Process text with SpaCy
                        for sent in doc.sents:
                            sentences.append(sent.text.strip())
                            pages.append(page_number)
                        logger.info(f"Extracted sentences from page: {page_number}")
                    else:
                        logger.warning(f"Empty sentence found in item: {item}")
                else:
                    logger.error(f"Missing keys in item: {item}")
            elif isinstance(item, tuple) and len(item) == 2:
                text = item[0].strip()
                page_number = item[1]
                doc = self.nlp(text)  # Process text with SpaCy
                for sent in doc.sents:
                    sentences.append(sent.text.strip())
                    pages.append(page_number)
            else:
                logger.error(f"Unexpected item format: {item}")

        # Organize sentences by page
        sentences_by_page = {}
        for sentence, page in zip(sentences, pages):
            sentences_by_page.setdefault(page, []).append(sentence)

        # Chunk sentences into fixed-size chunks and generate summaries
        for page, sentences in sentences_by_page.items():
            if not sentences:
                continue

            for i in range(0, len(sentences), self.max_sentences_per_chunk):
                chunk_sentences = sentences[i:i + self.max_sentences_per_chunk]
                chunk_text = " ".join(chunk_sentences)
                
                # Generate the summary for the chunk of sentences
                summary = self.generate_summary(chunk_text)

                # Generate additional information
                chunk_char_count = sum(len(s) for s in chunk_sentences)
                chunk_word_count = sum(len(s.split()) for s in chunk_sentences)
                chunk_token_count = sum(len(s) // 4 for s in chunk_sentences)
                summary_char_count = len(summary)
                summary_word_count = len(summary.split())

                # Create a dictionary with both chunk data and summary data
                chunk_dict = {
                    "sentence_chunk": chunk_text,
                    "chunk_char_count": chunk_char_count,
                    "chunk_word_count": chunk_word_count,
                    "chunk_token_count": chunk_token_count,
                    "page_number": page,  # Include the page number
                    "summary_text": summary,
                    "summary_char_count": summary_char_count,
                    "summary_word_count": summary_word_count,                    
                    "para_id" : self.generate_unique_id(chunk_text)
                }

                # Only include chunks with more than 30 tokens
                if chunk_token_count > 30:
                    #logger.info(f"Generated chunk and summary: {chunk_dict}")
                    pages_and_chunks.append(chunk_dict)

        #logger.info(f"Processed {len(pages_and_chunks)} semantic chunks with summaries.")
        return pages_and_chunks

# %% [markdown]
# # QuestionGenerator

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration, BertTokenizer, BertForQuestionAnswering
import torch
import pandas as pd

class QuestionAnswerGenerator:
    def __init__(self):
        # Load Doc2Query model for question generation
        self.model_name = 'doc2query/all-with_prefix-t5-base-v1'
        self.qgen_tokenizer = T5Tokenizer.from_pretrained(self.model_name)
        self.qgen_model = T5ForConditionalGeneration.from_pretrained(self.model_name)
        
        # Load BERT or similar model for Question Answering (QA)
        self.qa_tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
        self.qa_model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

    def generate_questions(self, chunk, num_questions=5):
        """
        Generate questions from a chunk of text using the Doc2Query model.

        :param chunk: The input chunk of text to generate questions for.
        :param num_questions: The number of questions to generate (default is 5).
        :return: A list of generated questions.
        """
        # Prepare the chunk for Doc2Query
        input_text = f"generate questions: {chunk}"
        inputs = self.qgen_tokenizer(input_text, return_tensors='pt', truncation=True, max_length=512)

        # Check if we are using greedy decoding or beam search
        if num_questions == 1:
            # Use greedy decoding for one question
            outputs = self.qgen_model.generate(
                **inputs, 
                max_length=50, 
                num_return_sequences=1,  # Only generate one question
                no_repeat_ngram_size=2
            )
        else:
            # Use beam search for multiple questions
            outputs = self.qgen_model.generate(
                **inputs, 
                max_length=150, 
                num_return_sequences=num_questions,  # Generate multiple questions
                num_beams=num_questions,  # Use beam search
                no_repeat_ngram_size=2
            )

        # Decode the generated questions
        questions = [self.qgen_tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
        return questions

    def generate_answers(self, chunk, questions):
        """
        Generate answers for a list of questions given a chunk of text.

        :param chunk: The input chunk of text for answering the questions.
        :param questions: A list of questions to answer.
        :return: A list of answers corresponding to the input questions.
        """
        answers = []
        for question in questions:
            # Encode the question and the context (chunk) for QA model with truncation and padding
            inputs = self.qa_tokenizer.encode_plus(
                question, 
                chunk, 
                return_tensors='pt', 
                truncation=True,  # Ensure the input sequence is truncated to fit the max length
                padding=True,     # Pad the sequence if it's shorter than the maximum length
                max_length=512    # Set the max length for the sequence
            )

            # Get the start and end positions of the answer
            outputs = self.qa_model(**inputs)

            # If the model outputs a tuple (start_scores, end_scores)
            if isinstance(outputs, tuple):
                answer_start_scores, answer_end_scores = outputs
            else:
                # If the model returns a dict, extract the start and end scores
                answer_start_scores = outputs['start_logits']
                answer_end_scores = outputs['end_logits']

            # Get the most likely beginning and end of the answer
            start_index = torch.argmax(answer_start_scores)
            end_index = torch.argmax(answer_end_scores)

            # Decode the answer from the token indices
            answer = self.qa_tokenizer.convert_tokens_to_string(
                self.qa_tokenizer.convert_ids_to_tokens(inputs['input_ids'][0][start_index:end_index+1])
            )

            answers.append(answer)
        return answers

    def transform(self, chunk_data):
        """
        Transform the input chunk data by generating questions and answers.

        :param chunk_data: A list of chunks, each containing a sentence chunk.
        :return: A list of chunks with generated questions and answers added.
        """
        all_chunk_qa = []
        for chunk in chunk_data:
            chunk_text = chunk['sentence_chunk']  # Get the text of the chunk
            questions = self.generate_questions(chunk_text)
            answers = self.generate_answers(chunk_text, questions)
            chunk['generated_questions'] = questions
            chunk['generated_answers'] = answers
            all_chunk_qa.append(chunk)
        return all_chunk_qa

# %% [markdown]
# #  Step 3: Chunk Sentences

# %%
class SentenceChunker(BaseEstimator, TransformerMixin):
    def __init__(self, max_sentences_per_chunk=5):
        self.max_sentences_per_chunk = max_sentences_per_chunk
        # Load the SpaCy English model and add the sentencizer
        self.nlp = spacy.blank("en")
        self.nlp.add_pipe("sentencizer")

    def fit(self, X, y=None):
        return self

    def transform(self, X, document_attributes=None):
        pages_and_chunks = []
        logger.info(f"Input data for transformation: {X}")
        logger.info(f"Input data length: {len(X)}")

        if not X:
            logger.warning("Input data is empty.")
            return []

        sentences = []
        pages = []

        # Extract sentences and page numbers
        for item in X:
            if isinstance(item, dict):
                if 'formatted_text' in item and 'page_number' in item:
                    text = item['formatted_text'].strip()
                    page_number = item['page_number']
                    if text:  # Check if text is not empty
                        doc = self.nlp(text)  # Process text with SpaCy
                        for sent in doc.sents:
                            sentences.append(sent.text.strip())
                            pages.append(page_number)
                        #logger.info(f"Extracted sentences from page: {page_number}")
                    else:
                        logger.warning(f"Empty sentence found in item: {item}")
                else:
                    logger.error(f"Missing keys in item: {item}")
            elif isinstance(item, tuple) and len(item) == 2:
                text = item[0].strip()
                page_number = item[1]
                doc = self.nlp(text)  # Process text with SpaCy
                for sent in doc.sents:
                    sentences.append(sent.text.strip())
                    pages.append(page_number)
            else:
                logger.error(f"Unexpected item format: {item}")

        # Organize sentences by pages
        sentences_by_page = {}
        for sentence, page in zip(sentences, pages):
            sentences_by_page.setdefault(page, []).append(sentence)

        for page, sentences in sentences_by_page.items():
            if not sentences:
                continue

            # Chunk sentences into fixed-size chunks
            for i in range(0, len(sentences), self.max_sentences_per_chunk):
                chunk_sentences = sentences[i:i + self.max_sentences_per_chunk]
                chunk_token_count = sum(len(s) // 4 for s in chunk_sentences)
                chunk_dict = {
                    "sentence_chunk": " ".join(chunk_sentences),
                    "chunk_char_count": sum(len(s) for s in chunk_sentences),
                    "chunk_word_count": sum(len(s.split()) for s in chunk_sentences),
                    "chunk_token_count": sum(len(s) // 4 for s in chunk_sentences),  # Adjust if needed
                    "page_number": page  # Include the page number
                }
                if chunk_token_count > 30:
                    logger.info(f"Generated chunk: {chunk_dict}")
                    pages_and_chunks.append(chunk_dict)

        logger.info(f"Processed {len(pages_and_chunks)} semantic chunks.")
        return pages_and_chunks

# %% [markdown]
# # Step 4: Generate Embeddings

# %%
class EmbeddingGenerator(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.model = SentenceTransformer(model_name_or_path="all-mpnet-base-v2", device="cuda")

    def fit(self, X, y=None):
        return self

    def transform(self, X, document_attributes):
        sentences = [chunk["sentence_chunk"] for chunk in X]
        embeddings = self.model.encode(sentences)
        
        for i, chunk in enumerate(X):
            chunk["embedding"] = embeddings[i]
        
        #log_output("Embedding Generator: "+ len(X))  # Log output
        return X

# %% [markdown]
# # Step 5: Save to ChromaDB

# %%
class ChromaDBSaver(BaseEstimator, TransformerMixin):
    def __init__(self, chroma_db_dir="chroma_db_dir"):  # Ensure this points to your local ChromaDB
        self.client = chromadb.PersistentClient(path=chroma_db_dir)
        self.collection = self.client.get_or_create_collection("pdf_chunks")

    def fit(self, X, y=None):
        return self

    def transform(self, X, document_attributes):
        i = 0 
        for chunk, doc_attr in zip(X, document_attributes):

            document_id = f"{doc_attr['make']}_{doc_attr['model']}_{doc_attr['year']}_{doc_attr['style']}"
            
            # Log the chunk being added
            text =  chunk["sentence_chunk"]
            chunk_char_count = chunk["chunk_char_count"]
            chunk_word_count = chunk["chunk_word_count"]
            if chunk["sentence_chunk"].strip():  # Ensure it's not empty
                #print(f"Adding document ID: {document_id}, Content: '{chunk['sentence_chunk']}'")
                
                self.collection.add(
                    documents=[text],
                    embeddings=[chunk["embedding"].tolist()],
                    metadatas=[{"source": document_id}],
                    ids = [f"{document_id}_{chunk['page_number']}_{chunk_word_count}_{chunk_char_count}"]

                )
            else:
                print(f"Skipping empty document for ID: {document_id}")
            i=i+1

        log_output("ChromaDB Saver , Data saved to ChromaDB")
        return X

# %% [markdown]
# # Main Pipeline Execution

# %%
def process_document(document):
    # Create the pipeline
    pipeline = Pipeline(steps=[
        ('pdf_reader', PDFReader),  # Step 1: Read PDF (pass the class, not an instance)
        ('text_formatter', TextFormatter()),  # Step 2: Format text
        ('bullet_point_transformer', BulletPointTransformer()),  # Step 3: Transform bullet points
        ('sentence_chunker', SentenceChunkerWithSummarization()),  # Step 4: Chunk sentences
        ('question_answer_generator', QuestionAnswerGenerator()),  # Step 5: Generate QA pairs (call the class)
        ('embedding_generator', EmbeddingGenerator()),  # Step 6: Generate embeddings
        ('chromadb_saver', ChromaDBSaver())  # Step 7: Save to ChromaDB
    ])

    # Create a document ID based on attributes
    document_id = f"{document['make']}_{document['model']}_{document['year']}_{document['style']}"

    # Instantiate PDFReader manually, as it requires the file path
    pdf_reader = PDFReader(document.get('pdf_path'))
    result = pdf_reader.fit_transform(document.get('pdf_path'))  # Read the PDF file

    # Process the document through each pipeline step
    result = pipeline.named_steps['text_formatter'].transform(result)
    result = pipeline.named_steps['bullet_point_transformer'].transform(result)
    result = pipeline.named_steps['sentence_chunker'].transform(result)
    result = pipeline.named_steps['question_answer_generator'].transform(result)  # Generate questions and answers

    # Generate embeddings and add them to the result
    embeddings = pipeline.named_steps['embedding_generator'].transform(result, document)

    # Save the embeddings and document data to ChromaDB
    pipeline.named_steps['chromadb_saver'].transform(embeddings, [document] * len(embeddings))

    # Process each chunk and add the data to the list
    all_chunk_data = []
    all_QandA =[]
    for chunk in result:
        chunk_data = {
            "sentence_chunk": chunk["sentence_chunk"],
            "chunk_char_count": chunk["chunk_char_count"],
            "chunk_word_count": chunk["chunk_word_count"],
            "chunk_token_count": chunk["chunk_token_count"],
            "page_number": chunk["page_number"],
            "summary_text": chunk["summary_text"],
            "summary_char_count": chunk["summary_char_count"],
            "summary_word_count": chunk["summary_word_count"],
            "para_id" : chunk["para_id"],               
        }
        for index, question in enumerate(chunk["generated_questions"], 0):
            qa_data  = {
               
               "page_number": chunk["page_number"],
               "para_id" : chunk["para_id"],   
               "sentence_chunk": chunk["sentence_chunk"],
               "question" : question,
               "answer" :  chunk["generated_answers"][index]
            }
            all_QandA.append(qa_data)
  
        all_chunk_data.append(chunk_data)

    # Convert the list of chunks into a pandas DataFrame
    df = pd.DataFrame(all_chunk_data)
    df_qa = pd.DataFrame(all_QandA)

    # Save the DataFrame to a CSV file
    df.to_csv("/app/manuals/" + document_id + ".csv", index=False)
    df_qa.to_csv("/app/manuals/" + document_id + "_QA.csv", index=False)

# %%
# Main Pipeline Execution
input_documents = [
    {
        "make": "Fraggles",
        "model": "X500",
        "year": "2024",
        "style": "FMS",
        "pdf_path": "/app/manuals/FragglesX500FMS-2024-V4.pdf"  
    },
    {
        "make": "Fraggles",
        "model": "X700",
        "year": "2022",
        "style": "HCM",
        "pdf_path": "/app/manuals/FragglesX700HCM-2022-V2.pdf"
    }
]

# Process each document
for doc in input_documents:
    process_document(doc)
# Out:
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-mpnet-base-v2
# Reading PDF pages:   0%|          | 0/97 [00:00<?, ?it/s]
# INFO:__main__:Successfully read 97 pages from /app/manuals/FragglesX500FMS-2024-V4.pdf
# INFO:__main__:Extracted sentences from page: 0
# INFO:__main__:Extracted sentences from page: 1
# INFO:__main__:Extracted sentences from page: 2
# INFO:__main__:Extracted sentences from page: 3
# INFO:__main__:Extracted sentences from page: 4
# INFO:__main__:Extracted sentences from page: 5
# INFO:__main__:Extracted sentences from page: 6
# INFO:__main__:Extracted sentences from page: 7
# INFO:__main__:Extracted sentences from page: 8
# INFO:__main__:Extracted sentences from page: 9
# INFO:__main__:Extracted sentences from page: 10
# INFO:__main__:Extracted sentences from page: 11
# INFO:__main__:Extracted sentences from page: 12
# INFO:__main__:Extracted sentences from page: 13
# INFO:__main__:Extracted sentences from page: 14
# INFO:__main__:Extracted sentences from page: 15
# INFO:__main__:Extracted sentences from page: 16
# INFO:__main__:Extracted sentences from page: 17
# INFO:__main__:Extracted sentences from page: 18
# INFO:__main__:Extracted sentences from page: 19
# INFO:__main__:Extracted sentences from page: 20
# INFO:__main__:Extracted sentences from page: 21
# INFO:__main__:Extracted sentences from page: 22
# INFO:__main__:Extracted sentences from page: 23
# INFO:__main__:Extracted sentences from page: 24
# INFO:__main__:Extracted sentences from page: 25
# INFO:__main__:Extracted sentences from page: 26
# INFO:__main__:Extracted sentences from page: 27
# INFO:__main__:Extracted sentences from page: 28
# INFO:__main__:Extracted sentences from page: 29
# INFO:__main__:Extracted sentences from page: 30
# INFO:__main__:Extracted sentences from page: 31
# INFO:__main__:Extracted sentences from page: 32
# INFO:__main__:Extracted sentences from page: 33
# INFO:__main__:Extracted sentences from page: 34
# INFO:__main__:Extracted sentences from page: 35
# INFO:__main__:Extracted sentences from page: 36
# INFO:__main__:Extracted sentences from page: 37
# INFO:__main__:Extracted sentences from page: 38
# INFO:__main__:Extracted sentences from page: 39
# INFO:__main__:Extracted sentences from page: 40
# INFO:__main__:Extracted sentences from page: 41
# INFO:__main__:Extracted sentences from page: 42
# INFO:__main__:Extracted sentences from page: 43
# INFO:__main__:Extracted sentences from page: 44
# INFO:__main__:Extracted sentences from page: 45
# INFO:__main__:Extracted sentences from page: 46
# INFO:__main__:Extracted sentences from page: 47
# INFO:__main__:Extracted sentences from page: 48
# INFO:__main__:Extracted sentences from page: 49
# INFO:__main__:Extracted sentences from page: 50
# INFO:__main__:Extracted sentences from page: 51
# INFO:__main__:Extracted sentences from page: 52
# INFO:__main__:Extracted sentences from page: 53
# INFO:__main__:Extracted sentences from page: 54
# INFO:__main__:Extracted sentences from page: 55
# INFO:__main__:Extracted sentences from page: 56
# INFO:__main__:Extracted sentences from page: 57
# INFO:__main__:Extracted sentences from page: 58
# INFO:__main__:Extracted sentences from page: 59
# INFO:__main__:Extracted sentences from page: 60
# INFO:__main__:Extracted sentences from page: 61
# INFO:__main__:Extracted sentences from page: 62
# INFO:__main__:Extracted sentences from page: 63
# INFO:__main__:Extracted sentences from page: 64
# INFO:__main__:Extracted sentences from page: 65
# INFO:__main__:Extracted sentences from page: 66
# INFO:__main__:Extracted sentences from page: 67
# INFO:__main__:Extracted sentences from page: 68
# INFO:__main__:Extracted sentences from page: 69
# INFO:__main__:Extracted sentences from page: 70
# INFO:__main__:Extracted sentences from page: 71
# INFO:__main__:Extracted sentences from page: 72
# INFO:__main__:Extracted sentences from page: 73
# INFO:__main__:Extracted sentences from page: 74
# INFO:__main__:Extracted sentences from page: 75
# INFO:__main__:Extracted sentences from page: 76
# INFO:__main__:Extracted sentences from page: 77
# INFO:__main__:Extracted sentences from page: 78
# INFO:__main__:Extracted sentences from page: 79
# INFO:__main__:Extracted sentences from page: 80
# INFO:__main__:Extracted sentences from page: 81
# INFO:__main__:Extracted sentences from page: 82
# INFO:__main__:Extracted sentences from page: 83
# INFO:__main__:Extracted sentences from page: 84
# INFO:__main__:Extracted sentences from page: 85
# INFO:__main__:Extracted sentences from page: 86
# INFO:__main__:Extracted sentences from page: 87
# INFO:__main__:Extracted sentences from page: 88
# INFO:__main__:Extracted sentences from page: 89
# INFO:__main__:Extracted sentences from page: 90
# INFO:__main__:Extracted sentences from page: 91
# INFO:__main__:Extracted sentences from page: 92
# INFO:__main__:Extracted sentences from page: 93
# INFO:__main__:Extracted sentences from page: 94
# INFO:__main__:Extracted sentences from page: 95
# INFO:__main__:Extracted sentences from page: 96
# Token indices sequence length is longer than the specified maximum sequence length for this model (564 > 512). Running this sequence through the model will result in indexing errors
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_1_40_373
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_1_40_373
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_2_173_1074
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_2_173_1074
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_2_176_1176
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_2_176_1176
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_2_78_509
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_2_78_509
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_3_167_1038
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_3_167_1038
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_3_129_809
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_3_129_809
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_3_151_871
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_3_151_871
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_4_194_1168
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_4_194_1168
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_4_158_1011
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_4_158_1011
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_4_29_185
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_4_29_185
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_5_148_945
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_5_148_945
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_5_153_982
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_5_153_982
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_5_123_760
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_5_123_760
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_6_198_1335
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_6_198_1335
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_6_189_1320
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_6_189_1320
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_7_156_1060
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_7_156_1060
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_7_166_1138
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_7_166_1138
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_7_32_262
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_7_32_262
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_8_229_1487
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_8_229_1487
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_8_158_984
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_8_158_984
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_8_24_172
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_8_24_172
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_9_193_1211
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_9_193_1211
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_9_188_1207
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_9_188_1207
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_9_30_215
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_9_30_215
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_10_208_1265
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_10_208_1265
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_10_148_932
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_10_148_932
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_11_126_751
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_11_126_751
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_11_211_1366
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_11_211_1366
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_12_200_1255
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_12_200_1255
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_12_211_1292
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_12_211_1292
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_12_23_137
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_12_23_137
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_13_215_1470
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_13_215_1470
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_13_154_1013
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_13_154_1013
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_14_196_1294
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_14_196_1294
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_14_106_603
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_14_106_603
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_14_60_382
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_14_60_382
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_15_163_1009
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_15_163_1009
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_15_152_967
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_15_152_967
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_15_45_279
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_15_45_279
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_16_218_1308
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_16_218_1308
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_16_187_1177
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_16_187_1177
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_17_116_688
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_17_116_688
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_17_202_1321
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_17_202_1321
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_17_35_205
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_17_35_205
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_18_95_592
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_18_95_592
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_18_155_966
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_18_155_966
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_18_77_491
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_18_77_491
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_19_173_1056
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_19_173_1056
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_19_113_637
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_19_113_637
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_19_69_399
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_19_69_399
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_19_28_144
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_19_28_144
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_20_167_1043
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_20_167_1043
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_20_181_1155
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_20_181_1155
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_20_22_135
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_20_22_135
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_21_201_1247
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_21_201_1247
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_21_139_924
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_21_139_924
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_22_209_1301
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_22_209_1301
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_22_145_947
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_22_145_947
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_23_143_889
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_23_143_889
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_23_141_860
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_23_141_860
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_23_44_259
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_23_44_259
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_24_100_571
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_24_100_571
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_24_77_398
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_24_77_398
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_24_141_841
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_24_141_841
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_24_40_270
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_24_40_270
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_25_126_766
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_25_126_766
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_25_155_956
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_25_155_956
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_25_52_341
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_25_52_341
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_26_66_358
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_26_66_358
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_26_123_726
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_26_123_726
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_26_155_966
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_26_155_966
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_27_189_1129
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_27_189_1129
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_27_126_761
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_27_126_761
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_27_31_202
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_27_31_202
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_28_220_1352
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_28_220_1352
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_28_120_764
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_28_120_764
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_29_181_1082
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_29_181_1082
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_29_166_1109
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_29_166_1109
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_30_177_1139
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_30_177_1139
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_30_143_951
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_30_143_951
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_30_23_162
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_30_23_162
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_31_158_1047
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_31_158_1047
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_31_128_849
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_31_128_849
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_32_103_633
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_32_103_633
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_32_197_1276
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_32_197_1276
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_32_28_194
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_32_28_194
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_33_139_830
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_33_139_830
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_33_141_800
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_33_141_800
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_33_48_321
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_33_48_321
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_34_182_1051
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_34_182_1051
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_34_162_1103
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_34_162_1103
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_35_138_872
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_35_138_872
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_35_150_926
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_35_150_926
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_35_103_599
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_35_103_599
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_36_148_877
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_36_148_877
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_36_164_919
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_36_164_919
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_36_94_557
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_36_94_557
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_37_129_746
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_37_129_746
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_37_157_1011
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_37_157_1011
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_37_53_383
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_37_53_383
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_38_105_613
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_38_105_613
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_38_164_1050
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_38_164_1050
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_38_125_800
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_38_125_800
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_39_128_848
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_39_128_848
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_39_106_647
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_39_106_647
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_39_118_750
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_39_118_750
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_40_122_753
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_40_122_753
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_40_105_681
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_40_105_681
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_40_103_645
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_40_103_645
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_41_75_416
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_41_75_416
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_41_105_593
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_41_105_593
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_41_121_685
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_41_121_685
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_41_69_423
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_41_69_423
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_42_124_842
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_42_124_842
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_42_116_694
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_42_116_694
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_42_58_347
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_42_58_347
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_43_126_777
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_43_126_777
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_43_120_722
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_43_120_722
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_43_94_581
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_43_94_581
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_44_147_911
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_44_147_911
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_44_104_693
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_44_104_693
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_44_70_426
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_44_70_426
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_45_102_698
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_45_102_698
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_45_144_873
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_45_144_873
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_45_52_374
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_45_52_374
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_46_96_591
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_46_96_591
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_46_125_882
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_46_125_882
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_46_139_938
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_46_139_938
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_47_131_943
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_47_131_943
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_47_106_649
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_47_106_649
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_47_76_479
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_47_76_479
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_48_95_587
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_48_95_587
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_48_88_500
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_48_88_500
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_48_71_359
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_48_71_359
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_48_84_457
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_48_84_457
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_48_51_265
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_48_51_265
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_49_147_937
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_49_147_937
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_49_141_823
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_49_141_823
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_49_52_290
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_49_52_290
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_49_57_335
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_49_57_335
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_50_136_860
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_50_136_860
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_50_95_603
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_50_95_603
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_50_72_415
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_50_72_415
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_50_55_353
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_50_55_353
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_51_124_796
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_51_124_796
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_51_94_563
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_51_94_563
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_51_111_718
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_51_111_718
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_52_102_616
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_52_102_616
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_52_107_644
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_52_107_644
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_52_115_792
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_52_115_792
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_53_110_672
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_53_110_672
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_53_81_504
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_53_81_504
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_53_88_531
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_53_88_531
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_53_50_341
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_53_50_341
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_54_156_930
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_54_156_930
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_54_84_477
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_54_84_477
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_54_130_804
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_54_130_804
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_55_144_905
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_55_144_905
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_55_97_604
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_55_97_604
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_55_96_533
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_55_96_533
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_55_30_208
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_55_30_208
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_56_153_970
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_56_153_970
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_56_131_846
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_56_131_846
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_56_104_634
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_56_104_634
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_57_180_1134
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_57_180_1134
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_57_135_895
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_57_135_895
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_57_57_380
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_57_57_380
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_58_96_593
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_58_96_593
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_58_107_645
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_58_107_645
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_58_82_591
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_58_82_591
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_58_62_407
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_58_62_407
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_59_146_938
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_59_146_938
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_59_150_946
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_59_150_946
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_59_68_398
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_59_68_398
# ...
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_76_70_431
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_76_70_431
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_77_163_1095
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_77_163_1095
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_77_200_1212
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_77_200_1212
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_78_119_725
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_78_119_725
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_78_103_595
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_78_103_595
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_78_130_767
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_78_130_767
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_78_25_160
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_78_25_160
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_79_197_1441
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_79_197_1441
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_79_55_438
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_79_55_438
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_80_96_653
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_80_96_653
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_80_95_627
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_80_95_627
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_80_116_742
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_80_116_742
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_81_86_547
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_81_86_547
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_81_62_389
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_81_62_389
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_81_73_447
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_81_73_447
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_81_88_531
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_81_88_531
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_81_52_323
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_81_52_323
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_82_162_1017
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_82_162_1017
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_82_85_545
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_82_85_545
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_82_123_838
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_82_123_838
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_83_70_442
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_83_70_442
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_83_133_830
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_83_133_830
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_83_90_555
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_83_90_555
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_83_33_232
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_83_33_232
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_84_98_682
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_84_98_682
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_84_180_1113
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_84_180_1113
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_84_101_668
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_84_101_668
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_85_73_458
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_85_73_458
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_85_64_370
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_85_64_370
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_85_56_315
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_85_56_315
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_85_72_454
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_85_72_454
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_85_43_250
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_85_43_250
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_85_43_251
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_85_43_251
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_86_126_798
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_86_126_798
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_86_194_1271
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_86_194_1271
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_86_28_201
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_86_28_201
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_87_182_1201
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_87_182_1201
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_87_164_975
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_87_164_975
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_87_61_405
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_87_61_405
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_88_114_713
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_88_114_713
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_88_137_843
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_88_137_843
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_88_113_749
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_88_113_749
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_89_107_698
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_89_107_698
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_89_205_1510
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_89_205_1510
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_89_24_134
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_89_24_134
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_90_151_1096
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_90_151_1096
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_90_120_884
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_90_120_884
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_90_83_624
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_90_83_624
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_91_166_1122
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_91_166_1122
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_91_156_1108
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_91_156_1108
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_92_173_1243
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_92_173_1243
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_92_165_1224
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_92_165_1224
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_93_288_2081
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_93_288_2081
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_94_125_886
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_94_125_886
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_94_144_982
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_94_144_982
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_94_67_453
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_94_67_453
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_95_305_2197
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_95_305_2197
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: Fraggles_X500_2024_FMS_96_164_1169
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: Fraggles_X500_2024_FMS_96_164_1169
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-mpnet-base-v2
# Reading PDF pages:   0%|          | 0/28 [00:00<?, ?it/s]
# INFO:__main__:Successfully read 28 pages from /app/manuals/FragglesX700HCM-2022-V2.pdf
# INFO:__main__:Extracted sentences from page: 0
# INFO:__main__:Extracted sentences from page: 1
# INFO:__main__:Extracted sentences from page: 2
# INFO:__main__:Extracted sentences from page: 3
# INFO:__main__:Extracted sentences from page: 4
# INFO:__main__:Extracted sentences from page: 5
# INFO:__main__:Extracted sentences from page: 6
# INFO:__main__:Extracted sentences from page: 7
# INFO:__main__:Extracted sentences from page: 8
# INFO:__main__:Extracted sentences from page: 9
# INFO:__main__:Extracted sentences from page: 10
# INFO:__main__:Extracted sentences from page: 11
# INFO:__main__:Extracted sentences from page: 12
# INFO:__main__:Extracted sentences from page: 13
# INFO:__main__:Extracted sentences from page: 14
# INFO:__main__:Extracted sentences from page: 15
# INFO:__main__:Extracted sentences from page: 16
# INFO:__main__:Extracted sentences from page: 17
# INFO:__main__:Extracted sentences from page: 18
# INFO:__main__:Extracted sentences from page: 19
# INFO:__main__:Extracted sentences from page: 20
# INFO:__main__:Extracted sentences from page: 21
# INFO:__main__:Extracted sentences from page: 22
# INFO:__main__:Extracted sentences from page: 23
# INFO:__main__:Extracted sentences from page: 24
# INFO:__main__:Extracted sentences from page: 25
# INFO:__main__:Extracted sentences from page: 26
# INFO:__main__:Extracted sentences from page: 27
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
class ChromaDBSearcher:
    def __init__(self, chroma_db_dir="chroma_db_dir", model_name="all-mpnet-base-v2"):
        self.client = chromadb.PersistentClient(path=chroma_db_dir)
        self.collection = self.client.get_collection("pdf_chunks")
        self.model = SentenceTransformer(model_name)

    def search_by_id(self, document_id, query):
        try:
            query_embedding = self.model.encode(query, convert_to_tensor=True).cpu().numpy()
            results = self.collection.query(
                query_embedding.tolist(),
                where={"source": document_source},
                n_results=5
            )
            
            if results and results['documents']:
                document_content = results['documents'][0]  # Remove extra spaces
                if document_content:
                    return results['documents']
                else:
                    print("Document content is empty.")
                    return None
            else:
                print("No documents found.")
                return None
        except Exception as e:
            print(f"An error occurred during search by ID: {e}")
            return None

# Example usage
searcher = ChromaDBSearcher()
document_source = "Fraggles_X500_2024_FMS"  # Replace with the actual document ID you want to search for
#document_source = "Ford_Mustang_2023_MACH-E"
query = "how to use parking breakes?"  # Replace with the query you want to search for

searcher.search_by_id(document_source, query)
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-mpnet-base-v2
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [['•  Traction control may be off, or the vehicle might be  in reverse (R). Ensure the vehicle is moving forward. Q: Why doesn’t the system offer a parking space? •  Sensors could be blocked or damaged, or there may  not be enough space for the vehicle to park safely. Q: Why isn’t the vehicle correctly positioned in the  parking space? •  The system may struggle with irregular curbs, high  attachments on nearby vehicles, or if the parking  space has changed after the vehicle has already  passed. Important Precautions  •  Always Remain in the Vehicle: You must stay in  control of the vehicle and be ready to intervene if  necessary.. FragglesX500FMS 2024          49  8. Release the brake pedal and allow the system to  maneuver the vehicle. 9. The vehicle will back into the parking space and shift  into park (P) when complete.',
#   'Tap the Active Park Assist icon on the touchscreen. 3. Select Perpendicular Parking mode. 4. Use the turn signal to indicate the side you want to  park. 5. Drive about 3 ft (1 m) away from parked vehicles. 6. The system detects the space; press and hold the  brake pedal. 7.',
#   'Shift into neutral (N), then press and hold the  Parking Aid button. 8. Release the brake pedal and let the system control  the vehicle as it parks. 9. When the parking maneuver is complete, the vehicle  shifts into park (P). Tips:  •  You can slow down the vehicle at any time by  pressing the brake pedal. •  The system parks closer to the object in front for  easier access to the trunk. Entering a Perpendicular Parking Space  1. Press the Parking Aid button. 2.',
#   'Press the Active Park Assist icon on the  touchscreen to enable the system. 3. Choose the desired parking mode:  o Parallel Park In  o Perpendicular Park In  o Parallel Park Out  Cancelling Active Park Assist:  •  Shift out of neutral (N) to cancel the system. •  To pause, release the parking aid button. Resuming Active Park Assist:  •  Press and hold the parking aid button again. Entering a Parallel Parking Space  1. Press the Parking Aid button. 2. Tap the Active Park Assist icon on the touchscreen. 3.',
#   'Use the turn signal to indicate the side of the vehicle  where you want to park. o If no turn signal is used, the system defaults  to searching on the passenger side. 4. Drive your vehicle about 3 ft (1 m) away from parked  vehicles. 5. Wait for the system to detect a suitable parking  space. A tone sounds and a message appears. 6. Press and hold the brake pedal. 7.']]
